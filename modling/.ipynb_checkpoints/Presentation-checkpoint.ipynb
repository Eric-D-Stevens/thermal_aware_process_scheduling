# %%
# needed
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
import mpld3
from dataset import dataset
# %matplotlib inline

mpld3.enable_notebook()
plt.style.use('seaborn')

# %% [markdown]
# # Loading the data files

# %%
ds = dataset()
ds.build_train_set()

# %%
ds.training_data.head()
# Out:
#      temp  delta_t  PERF_COUNT_HW_CPU_CYCLES  PERF_COUNT_HW_INSTRUCTIONS  \
# 0  62.300      1.0              1.199985e+09                8.310124e+08
# 1  61.762      1.0              1.199977e+09                8.306503e+08
# 2  61.762      1.0              1.199975e+09                8.310653e+08
# 3  54.768      1.0              1.199231e+09                8.302566e+08
# 4  57.996      1.0              1.199987e+09                8.308158e+08
#
#    PERF_COUNT_HW_CACHE_MISSES  PERF_COUNT_HW_BRANCH_MISSES  \
# 0                4.346978e+06                 1.878702e+06
# 1                4.324211e+06                 1.888496e+06
# 2                4.324632e+06                 1.880092e+06
# 3                4.344256e+06                 1.883425e+06
# 4                4.353805e+06                 1.882896e+06
#
#    PERF_COUNT_HW_BRANCH_INSTRUCTIONS  PERF_COUNT_HW_CACHE_LL_read_miss  \
# 0                       1.012176e+08                      14039.838257
# 1                       1.012061e+08                      17037.944722
# 2                       1.012330e+08                      14769.603652
# 3                       1.011288e+08                      18022.032256
# 4                       1.011926e+08                      16430.238766
#
#    PERF_COUNT_HW_CACHE_L1D_read_miss    d_temp
# 0                       4.347017e+06  0.020678
# 1                       4.324250e+06  0.053663
# 2                       4.324668e+06  0.026206
# 3                       4.344293e+06  0.096462
# 4                       4.353841e+06  0.070482

# %% [markdown]
# # Scaling the data

# %%
# get the inputs and targets
X = ds.training_data.drop('d_temp', axis=1).to_numpy()
y = ds.training_data.d_temp.to_numpy()

# scale the data
scaler = MinMaxScaler()
Xs = scaler.fit_transform(X)

# show scaled data
pd.DataFrame(Xs, columns=ds.training_data.columns[:-1]).head()
# Out:
#        temp  delta_t  PERF_COUNT_HW_CPU_CYCLES  PERF_COUNT_HW_INSTRUCTIONS  \
# 0  0.571429      0.0                  0.999927                    0.850458
# 1  0.535714      0.0                  0.999920                    0.850077
# 2  0.535714      0.0                  0.999919                    0.850514
# 3  0.071429      0.0                  0.999277                    0.849663
# 4  0.285714      0.0                  0.999929                    0.850252
#
#    PERF_COUNT_HW_CACHE_MISSES  PERF_COUNT_HW_BRANCH_MISSES  \
# 0                    0.742220                     0.101336
# 1                    0.738318                     0.101987
# 2                    0.738390                     0.101429
# 3                    0.741754                     0.101650
# 4                    0.743391                     0.101615
#
#    PERF_COUNT_HW_BRANCH_INSTRUCTIONS  PERF_COUNT_HW_CACHE_LL_read_miss  \
# 0                           0.832891                          0.004551
# 1                           0.832793                          0.006105
# 2                           0.833021                          0.004929
# 3                           0.832138                          0.006615
# 4                           0.832679                          0.005790
#
#    PERF_COUNT_HW_CACHE_L1D_read_miss
# 0                           0.742220
# 1                           0.738318
# 2                           0.738389
# 3                           0.741753
# 4                           0.743390

# %% [markdown]
# # Modeling

# %%
# create regressor
LM = linear_model.Ridge(alpha=1)

# train model
LM.fit(Xs, y)

# show trained model coefs
pd.DataFrame(LM.coef_, columns=['coef'], index=ds.training_data.columns[:-1])
# Out:
#                                        coef
# temp                              -0.232662
# delta_t                            0.000000
# PERF_COUNT_HW_CPU_CYCLES           0.188472
# PERF_COUNT_HW_INSTRUCTIONS         0.158650
# PERF_COUNT_HW_CACHE_MISSES        -0.002571
# PERF_COUNT_HW_BRANCH_MISSES        0.642190
# PERF_COUNT_HW_BRANCH_INSTRUCTIONS  0.158914
# PERF_COUNT_HW_CACHE_LL_read_miss   0.151347
# PERF_COUNT_HW_CACHE_L1D_read_miss -0.002554

# %% [markdown]
# # Predict on testing data

# %%
for fname in ds.test_files:

    # load the test file with target calculated
    tdf = dataset._delta_temp_column(fname)

    # get the target
    truth = tdf.d_temp.to_numpy()

    # drop target from model input
    tdf = tdf.drop('d_temp', axis=1)

    # SCALE AND PREDICT
    tdfs = scaler.transform(tdf)
    pred = LM.predict(tdfs)

    # plot
    plt.figure(figsize=(10,5))
    plt.ylim((-5,20))
    plt.title(fname)
    plt.plot(range(len(truth)), np.cumsum(truth), 'g.-')
    plt.plot(range(len(pred)), np.cumsum(pred), 'r.-')
